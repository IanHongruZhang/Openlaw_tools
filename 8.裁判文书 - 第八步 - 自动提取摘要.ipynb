# %% [markdown]
# ##### 第一模块(导入包模块：必须运行）

# %%
### 引入所有包,如果缺少某个包，包的名字附于之后
import numpy as np
# numpy

import pandas as pd
# pandas

import requests
# requests

from bs4 import BeautifulSoup
# BeautifulSoup

import re
# re

from fake_useragent import UserAgent
# fake-useragent

import json
# json

import time
# time

import random
# random

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
# selenium

from PIL import Image,ImageEnhance
# PIL

import hashlib
# hashlib

from collections import Counter
# collections

from gensim import corpora, models, similarities
# gensim 

import codecs, sys
# codecs

import os
# os

import time
#time

import shutil
# shutil

import jieba
# jieba

from pyhanlp import *
# pyhanlp，注意hanlp需要java的工具

import jpype
# jpype

import tensorflow as tf
# tensorflow

import matplotlib.pyplot as plt
# matplotlib

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn import feature_extraction  
from sklearn.feature_extraction.text import TfidfTransformer  
from sklearn.feature_extraction.text import CountVectorizer
# sklearn

from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LAParams
from pdfminer.pdfparser import PDFParser, PDFDocument
from pdfminer.pdfdevice import PDFDevice
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
# pdfminer3k

from tkinter import *
from tkinter import filedialog
# tk文件导入模块

# %% [markdown]
# ##### 第二模块(文件处理模块：必须运行）

# %%
def import_table(root):
    """
    return table:选中的表格
    """
    try:
        root.filename =  filedialog.askopenfilename(filetypes=(("xlsx", "*.xlsx"),("xlsx", "*.xlsx")))        
        if ".xlsx" in root.filename:
            ### 该目录下有该文件
            table = pd.read_excel(root.filename)
            root.destroy()
            return table
    except Exception as e:
        root.destroy()
        print("导入错误")

def remote_select():
    print("以下文件可以调用，需要分析哪个文件？")
    print("-------------------------------------")
    index = 0
    list_item_temp = []
    for item in os.listdir():
        if ".xlsx" in item:
            index += 1
            print("[" + str(index) + "] " + item)
            list_item_temp.append(item)
    try:
        bash_pos = "/Users/dfuser/Desktop/目标文书目录/"
        file_code = int(input("需要导入哪个文件？(输入[]中的序号)"))
        final_pos = bash_pos + str(list_item_temp[file_code-1])
        table_ = pd.read_excel(final_pos)
        return table_
        print("表格导入成功，以下是表格预览")
        print("----------------------------")
    except Exception as e:
        print("导入错误") 
        
def save_model(table):
    print("-------------------------------------------")
    print("以下为表格的预览:")
    print(table.head())
    flag = input("是否需要保存该词频表？(输入Y/N):")
    try:
        if flag == "Y":
            save_file_name = input("请输入该词频表格的名称(不用加.xlsx):")
            save_file_name_xlsx = save_file_name + ".xlsx"
            table.to_excel(save_file_name_xlsx)
        else:
            pass
    except Exception as e:
        pass

# %% [markdown]
# #### 控制部分

# %%
## 摘要
from pyhanlp import *
import jpype

def segment_summaries(article,summries_nums):
    TextRankSentence = JClass("com.hankcs.hanlp.summary.TextRankSentence")
    sentence_list = list(HanLP.extractSummary(article,summries_nums))
    return sentence_list

def run_segment_summaries(corpus,summries_nums):
    list_summary = []
    for article in corpus:
        try:
            summ = segment_summaries(article,summries_nums)
            list_summary.append(summ)
        except Exception as e:
            pass
    return list_summary

## 至少是五个主题，然后来做测试
## 摘要并入列表
if __name__ == '__main__':
    flag_input = int(input("你是在本机上操作？还是远程操作？(1:本机操作,2:远程操作)"))
    if flag_input == 1:
        root = Tk() # 实例化TKinter窗口
        root.withdraw() # 隐藏TKinter窗口
        table_ready_to_eat = import_table(root)
    elif flag_input == 2:
        table_ready_to_eat = remote_select()
    else:
        logging.error("加载错误")

    print("表格中所有的列:",table_ready_to_eat.columns)
    selected_column = input("请问需要分析哪一列的关键词词频？(输入关键词部分):")
    corpus = table_ready_to_eat[selected_column] #此处要留出选择模块的口子
    summaries_nums = int(input("请输入需要的摘要数量(请输入数字):"))
    table_summary = pd.DataFrame(run_segment_summaries(corpus,summaries_nums))
    table_summary.columns = list(map(lambda x,y:x+str(y),len(table_summary.columns) * ["摘要"],list(range(1,len(table_summary.columns) + 1))))
    table_HanLp_Summaries = table_ready_to_eat.join(table_summary)
    save_model(table_HanLp_Summaries)
# Out:
# 你是在本机上操作？还是远程操作？(1:本机操作,2:远程操作)2
# 以下文件可以调用，需要分析哪个文件？
# -------------------------------------
# [1] 夫妻债务 - 原表.xlsx
# [2] 校园暴力 - 结构化重构.xlsx
# [3] 校园暴力事件 - 原表.xlsx
# [4] 正当防卫 - 原表.xlsx
# [5] .~zhaiwu_regex_filter.xlsx.xlsx
# [6] 职业打假人 - 原表.xlsx
# 需要导入哪个文件？(输入[]中的序号)6
# 表格中所有的列: Index(['标题', '案号', '案件类型', '庭审程序', '案由', '文书类型', '法院', '判决日期', '原告', '被告',
#        '第三人', '法官', '审判长', '审判员', '书记员', '头部', '头部2', '当事人', '当事人2', '庭审程序说明',
#        '庭审程序说明2', '庭审过程', '庭审过程2', '庭审过程3', '庭审过程4', '庭审过程5', '庭审过程6', '法院意见',
#        '法院意见2', '判决结果', '判决结果2', '庭后告知', '庭后告知2', '结尾', '结尾2', '附录', '附录2'],
#       dtype='object')
# 请问需要分析哪一列的关键词词频？(输入关键词部分):判决结果
# 请输入需要的摘要数量(请输入数字):5
# -------------------------------------------
# 以下为表格的预览:
#                                 标题                  案号 案件类型 庭审程序      案由 文书类型  \
# 0   满洲里双实肉类食品有限公司与王晶等买卖合同纠纷一审民事判决书   （2019）内0703民初453号   民事   一审  买卖合同纠纷  判决书
# 1  刘春雪与重庆市永川区康牛商业有限公司买卖合同纠纷一审民事判决书  （2019）渝0118民初4448号   民事   一审  买卖合同纠纷  判决书
# 2  刘春雪与重庆市永川区康牛商业有限公司买卖合同纠纷一审民事判决书  （2019）渝0118民初4450号   民事   一审  买卖合同纠纷  判决书
# 3  刘春雪与重庆市永川区康牛商业有限公司买卖合同纠纷一审民事判决书  （2019）渝0118民初4444号   民事   一审  买卖合同纠纷  判决书
# 4  刘春雪与重庆市永川区康牛商业有限公司买卖合同纠纷一审民事判决书  （2019）渝0118民初4442号   民事   一审  买卖合同纠纷  判决书
#
#                      法院         判决日期             原告              被告  ...  \
# 0  内蒙古自治区呼伦贝尔市扎赉诺尔区人民法院  2019年07月20日  满洲里双实肉类食品有限公司           王晶、贾震  ...
# 1            重庆市永川区人民法院  2019年06月27日            刘春雪  重庆市永川区康牛商业有限公司  ...
# 2            重庆市永川区人民法院  2019年06月27日            刘春雪  重庆市永川区康牛商业有限公司  ...
# 3            重庆市永川区人民法院  2019年06月27日            刘春雪  重庆市永川区康牛商业有限公司  ...
# 4            重庆市永川区人民法院  2019年06月27日            刘春雪  重庆市永川区康牛商业有限公司  ...
#
#   庭后告知2                       结尾 结尾2  \
# 0   NaN   审判员魏岚、二〇一九年七月二十日、书记员姜璇 NaN
# 1   NaN  审判员雷宇、二〇一九年六月二十七日、书记员杨何 NaN
# 2   NaN  审判员雷宇、二〇一九年六月二十七日、书记员杨何 NaN
# 3   NaN  审判员雷宇、二〇一九年六月二十七日、书记员杨何 NaN
# 4   NaN  审判员雷宇、二〇一九年六月二十七日、书记员杨何 NaN
#
#                                                   附录 附录2  \
# 0  附:本案判决所依据的法律、一、《中华人民共和国合同法》第十条:当事人订立合同，有书面形式、口... NaN
# 1                                                NaN NaN
# 2                                                NaN NaN
# 3                                                NaN NaN
# 4                                                NaN NaN
#
#                                              摘要1  \
# 0   、一、被告王晶、贾震于判决生效后十日内给付原告满洲里双实肉类食品有限公司货款44007元
# 1  、限被告重庆市永川区康牛商业有限公司于本判决生效之日起三日内支付原告刘春雪赔偿金1000元
# 2  、限被告重庆市永川区康牛商业有限公司于本判决生效之日起三日内支付原告刘春雪赔偿金1000元
# 3  、限被告重庆市永川区康牛商业有限公司于本判决生效之日起三日内支付原告刘春雪赔偿金1000元
# 4  、限被告重庆市永川区康牛商业有限公司于本判决生效之日起三日内支付原告刘春雪赔偿金1390元
#
#                                                  摘要2  \
# 0                              、如果未按本判决指定的期间履行给付金钱义务
# 1  《最高人民法院》第四条《中华人民共和国民事诉讼法》第六十四条第一款、第一百六十二条、第二百七十一条
# 2  《最高人民法院》第四条《中华人民共和国民事诉讼法》第六十四条第一款、第一百六十二条、第二百七十一条
# 3  《最高人民法院》第四条《中华人民共和国民事诉讼法》第六十四条第一款、第一百六十二条、第二百七十一条
# 4  《最高人民法院》第四条《中华人民共和国民事诉讼法》第六十四条第一款、第一百六十二条、第二百七十一条
#
#                                 摘要3                          摘要4  \
# 0  《中华人民共和国民事诉讼法》第六十四条第一款、第一百四十四条规定  应当依照《中华人民共和国民事诉讼法》第二百五十三条规定
# 1      应当依照《中华人民共和国民事诉讼法》第二百五十三条之规定        、如果未按本判决指定的期间履行金钱给付义务
# 2      应当依照《中华人民共和国民事诉讼法》第二百五十三条之规定        、如果未按本判决指定的期间履行金钱给付义务
# 3      应当依照《中华人民共和国民事诉讼法》第二百五十三条之规定        、如果未按本判决指定的期间履行金钱给付义务
# 4      应当依照《中华人民共和国民事诉讼法》第二百五十三条之规定        、如果未按本判决指定的期间履行金钱给付义务
#
#                           摘要5
# 0  、二、驳回原告满洲里双实肉类食品有限公司其他诉讼请求
# 1         由被告重庆市永川区康牛商业有限公司承担
# 2         由被告重庆市永川区康牛商业有限公司承担
# 3         由被告重庆市永川区康牛商业有限公司承担
# 4         由被告重庆市永川区康牛商业有限公司承担
#
# [5 rows x 42 columns]
# 是否需要保存该词频表？(输入Y/N):N
