# %%
### 引入所有包,如果缺少某个包，包的名字附于之后
import numpy as np
# numpy

import pandas as pd
# pandas

import requests
# requests

from bs4 import BeautifulSoup
# BeautifulSoup

import re
# re

from fake_useragent import UserAgent
# fake-useragent

import json
# json

import time
# time

import random
# random

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
# selenium

from PIL import Image,ImageEnhance
# PIL

import hashlib
# hashlib

from collections import Counter
# collections

from gensim import corpora, models, similarities
# gensim 

import codecs, sys
# codecs

import os
# os

import time
#time

import shutil
# shutil

import jieba
# jieba

from pyhanlp import *
# pyhanlp，注意hanlp需要java的工具

import jpype
# jpype

import tensorflow as tf
# tensorflow

import matplotlib.pyplot as plt
# matplotlib

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn import feature_extraction  
from sklearn.feature_extraction.text import TfidfTransformer  
from sklearn.feature_extraction.text import CountVectorizer
# sklearn

from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LAParams
from pdfminer.pdfparser import PDFParser, PDFDocument
from pdfminer.pdfdevice import PDFDevice
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
# pdfminer3k

from tkinter import *
from tkinter import filedialog
# tk文件导入模块

# %%
def import_table(root):
    """
    return table:选中的表格
    """
    try:
        root.filename =  filedialog.askopenfilename(filetypes=(("xlsx", "*.xlsx"),("xlsx", "*.xlsx")))        
        if ".xlsx" in root.filename:
            ### 该目录下有该文件
            table = pd.read_excel(root.filename)
            root.destroy()
            return table
    except Exception as e:
        root.destroy()
        print("导入错误")

def save_model(table):
    print("-------------------------------------------")
    print("以下为表格的预览:")
    print(table.head())
    flag = input("是否需要保存该词频表？(输入Y/N):")
    try:
        if flag == "Y":
            save_file_name = input("请输入该词频表格的名称(不用加.xlsx):")
            save_file_name_xlsx = save_file_name + ".xlsx"
            table.to_excel(save_file_name_xlsx)
        else:
            pass
    except Exception as e:
        pass

# %%
## 摘要
from pyhanlp import *
import jpype

def segment_summaries(article,summries_nums):
    TextRankSentence = JClass("com.hankcs.hanlp.summary.TextRankSentence")
    sentence_list = list(HanLP.extractSummary(article,summries_nums))
    return sentence_list

def run_segment_summaries(corpus,summries_nums):
    list_summary = []
    for article in corpus:
        summ = segment_summaries(article,summries_nums)
        list_summary.append(summ)
    return list_summary

## 至少是五个主题，然后来做测试
## 摘要并入列表
if __name__ == '__main__':
    root = Tk() # 实例化TKinter窗口
    root.withdraw() # 隐藏TKinter窗口
    table_ready_to_eat = import_table(root)
    print("----------------------------------------------")
    print("*****表格已经导入******")
    print("----------------------------------------------")
    print("表格中所有的列:",table_ready_to_eat.columns)
    selected_column = input("请问需要分析哪一列的关键词词频？(输入关键词部分):")
    corpus = table_ready_to_eat[selected_column] #此处要留出选择模块的口子
    summaries_nums = int(input("请输入需要的摘要数量(请输入数字):"))
    table_summary = pd.DataFrame(run_segment_summaries(corpus,summaries_nums))
    table_summary.columns = list(map(lambda x,y:x+str(y),len(table_summary.columns) * ["摘要"],list(range(1,len(table_summary.columns) + 1))))
    table_HanLp_Summaries = table_ready_to_eat.join(table_summary)
    save_model(table_HanLp_Summaries)
# Out:
# ----------------------------------------------
# *****表格已经导入******
# ----------------------------------------------
# 表格中所有的列: Index(['标题', '案号', '案件类型', '庭审程序', '案由', '文书类型', '法院', '判决日期', '原告', '被告',
#        '第三人', '法官', '审判长', '审判员', '书记员', '头部', '头部2', '当事人', '当事人2', '庭审程序说明',
#        '庭审程序说明2', '庭审过程', '庭审过程2', '庭审过程3', '庭审过程4', '庭审过程5', '庭审过程6', '法院意见',
#        '法院意见2', '判决结果', '判决结果2', '庭后告知', '庭后告知2', '结尾', '结尾2', '附录', '附录2',
#        'results', '符合要求的案件'],
#       dtype='object')
# 请问需要分析哪一列的关键词词频？(输入关键词部分):判决结果
# 请输入需要的摘要数量(请输入数字):5
# -------------------------------------------
# 以下为表格的预览:
#                                   标题               案号 案件类型 庭审程序      案由 文书类型  \
# 0  上诉人官建坤与被上诉人蔡秀英及张兰英民间借贷纠纷一案再审民事判决书    （2018）川10民再3号   民事   再审  民间借贷纠纷  判决书
# 1               胡祝荣、刘汉雄民间借贷纠纷再审民事判决书  （2018）鄂1222民再1号   民事   再审  民间借贷纠纷  判决书
# 2               胡宇新、魏文祥民间借贷纠纷再审民事判决书   （2018）津01民再15号   民事   再审  民间借贷纠纷  判决书
# 4                张薇、何红军民间借贷纠纷再审民事判决书   （2018）川13民再31号   民事   再审  民间借贷纠纷  判决书
# 6               李金山、徐忠国民间借贷纠纷再审民事判决书  （2018）豫01民再184号   民事   再审  民间借贷纠纷  判决书
#
#              法院         判决日期   原告       被告  \
# 0  四川省内江市中级人民法院  2018年05月03日  官建坤  蔡秀英、张兰英
# 1       通城县人民法院  2018年03月21日  胡祝荣  刘汉雄、陈仲华
# 2   天津市第一中级人民法院  2018年03月22日  胡宇新  魏文祥、雷若寒
# 4  四川省南充市中级人民法院  2018年08月03日   张薇  何红军、余宗军
# 6  河南省郑州市中级人民法院  2018年09月29日  李金山   徐忠国、刘影
#
#                          ...                         结尾2  \
# 0                        ...                         NaN
# 1                        ...                         NaN
# 2                        ...                         NaN
# 4                        ...                         NaN
# 6                        ...                         NaN
#
#                                                   附录 附录2  results 符合要求的案件  \
# 0                                                NaN NaN     True    True
# 1  附:相关法律、法规条文、《中华人民共和国民事诉讼法》、第一百四十四条被告经传票传唤，无正当理... NaN     True    True
# 2  附:本裁判文书所依据法律规定的具体条文:、1、最高人民法院《关于审理涉及夫妻债务纠纷案件适用... NaN     True    True
# 4                                                NaN NaN     True    True
# 6                                                NaN NaN     True    True
#
#                                                  摘要1  \
# 0                                     由被上诉人蔡秀英负担715元
# 1                              、如果未按本判决指定的期间履行给付金钱义务
# 2                                     共计18768元由雷若寒负担
# 4                          、维持本院（2017）豫01民终5672号民事判决
# 6  、三、王百建、刘长珍、王龙、王佳佳于本判决生效之日起七日内共同偿还陈美霞借款本金209200...
#
#                                                  摘要2  \
# 0                                     由被上诉人蔡秀英负担715元
# 1                                    加倍支付迟延履行期间的债务利息
# 2                              、如果未按本判决指定的期间履行给付金钱义务
# 4                                               None
# 6  、二、王百建、刘长珍、王龙、刘娟娟于本判决生效之日起七日内共同偿还陈美霞借款本金397903...
#
#                                           摘要3  \
# 0                             由被上诉人张兰英负担2300元
# 1                应当按照《中华人民共和国民事诉讼法》第二百五十三条之规定
# 2  、二、雷若寒于本判决书生效后十日内偿还魏文祥两笔借款本金60万元、利息268800元
# 4                                        None
# 6                应当按照《中华人民共和国民事诉讼法》第二百五十三条之规定
#
#                                                  摘要4  \
# 0                                      、二审案件受理费3015元
# 1  、一、由原审被告陈仲华在本判决书生效后十日内偿还被申请人刘汉雄的借款本金30000元及利息（...
# 2                                      二审案件受理费12488元
# 4                                               None
# 6                          由王百建、刘长珍、王龙、王佳佳共同负担25400元
#
#                                                  摘要5
# 0  依照《最高人民法院关于审理涉及夫妻债务纠纷案件适用法律有关问题的解释》第三条、《中华人民共和...
# 1                                         由被申请人刘汉雄承担
# 2  依照最高人民法院《关于审理涉及夫妻债务纠纷案件适用法律有关问题的解释》第三条、《中华人民共和...
# 4                                               None
# 6                        由王百建、刘长珍、刘娟娟、王龙、张涛共同负担4800元
#
# [5 rows x 44 columns]
# 是否需要保存该词频表？(输入Y/N):N
